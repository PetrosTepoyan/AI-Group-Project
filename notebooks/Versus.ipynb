# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from GameFlow.Versus import Versus

# %%
v_runner = Versus(6, 6, 5)
v_runner.start()
# Out:
#     0   1   2   3   4
#   ---------------------
# 0 |   |   | X |   |   |
#   --------------------
# 1 |   |   |   |   |   |
#   --------------------
# 2 |   |   |   |   |   |
#   --------------------
# 3 |   |   |   |   |   |
#   --------------------
# 4 |   |   | O |   |   |
#   ---------------------
# Board Player.MIN | MAX:(1, 0) - MIN:(2, 4) | 1 | 1 3
# Board Player.MIN | MAX:(1, 0) - MIN:(2, 4) | 1 | 1 3
# Board Player.MIN | MAX:(3, 0) - MIN:(2, 4) | 1 | 1 3
# Board Player.MIN | MAX:(3, 0) - MIN:(2, 4) | 1 | 1 3
# Board Player.MIN | MAX:(2, 0) - MIN:(3, 4) | 2 | 2 2
# Board Player.MIN | MAX:(1, 0) - MIN:(2, 4) | 1 | 1 3
# Board Player.MIN | MAX:(1, 0) - MIN:(2, 4) | 1 | 1 3
# Board Player.MIN | MAX:(3, 0) - MIN:(2, 4) | 1 | 1 3
# Board Player.MIN | MAX:(3, 0) - MIN:(2, 4) | 1 | 1 3
# Board Player.MIN | MAX:(2, 0) - MIN:(3, 4) | 2 | 2 2
#     0   1   2   3   4
#   ---------------------
# 0 |   | X |   |   |   |
#   --------------------
# 1 |   |   |   |   |   |
# ...
